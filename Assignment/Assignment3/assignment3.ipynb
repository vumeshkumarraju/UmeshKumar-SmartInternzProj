# %% [markdown]
# <h3> V Umesh Kumar Raju </h3>
# <h3> 20MIS0187 </h3>
# <h3> VIT Vellore </h3>
#
#
# <h2> ASSIGNMENT 3 </H3>
#
#
# <h4>Description:- House price prediction is a common problem in the real estate industry and involves predicting the selling price of a house based on various features and attributes. The problem is typically approached as a regression problem, where the target variable is the price of the house, and the features are various attributes of the house.
# <br>
# The features used in house price prediction can include both quantitative and categorical variables, such as the number of bedrooms, house area, bedrooms, furnished, nearness to main road, and various amenities such as a garage and other factors that may influence the value of the property.
# <br>
# Accurate predictions can help agents and appraisers price homes correctly, while homeowners can use the predictions to set a reasonable asking price for their properties. Accurate house price prediction can also be useful for buyers who are looking to make informed decisions about purchasing a property and obtaining a fair price for their investment.</h4>
#
# <h4>
# Name - Description<br>
# 1- Price-Prices of the houses<br>
# 2- Area- Area of the houses<br>
# 3- Bedrooms- No of house bedrooms<br>
# 4- Bathrooms- No of bathrooms<br>
# 5- Stories- No of house stories<br>
# 6- Main Road- Weather connected to Main road<br>
# 7- Guestroom-Weather has a guest room<br>
# 8- Basement-Weather has a basement<br>
# 9- Hot water heating- Weather has a hot water heater 10-Airconditioning-Weather has a air conditioner 11-Parking- No of house parking<br>
# 12-Furnishing Status-Furnishing status of house<br>
# </h4>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h4> 1. Download the dataset
# <br>2. Load the dataset into the tool.</h4>

# %%
df = pd.read_csv("Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
df.value_counts()
# Out:
# price     area   bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 1750000   2910   3         1          1        no        no         no        no               no               0        furnished           1
# 5229000   7085   3         1          1        yes       yes        yes       no               no               2        semi-furnished      1
# 5110000   11410  2         1          2        yes       no         no        no               no               0        furnished           1
# 5145000   3410   3         1          2        no        no         no        no               yes              0        semi-furnished      1
#           7980   3         1          1        yes       no         no        no               no               1        semi-furnished      1
# ...

# %%
df.furnishingstatus.value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %% [markdown]
# <h4>3. Perform Below Visualizations. <br>
#  Univariate Analysis <br>
#  Bi-Variate Analysis <br>
#  Multi-Variate Analysis </h4>

# %%
plt.pie(df.furnishingstatus.value_counts(), labels = df.furnishingstatus.value_counts().index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x12be9fcd0>,
# ...
#  [Text(0.28521128309432414, 1.0623815340995388, 'semi-furnished'),
#   Text(-0.9645476294288756, -0.5288174264934321, 'unfurnished'),
#   Text(0.7608233961924185, -0.7944480850289933, 'furnished')],
#  [Text(0.15556979077872224, 0.5794808367815666, '41.7%'),
#   Text(-0.5261168887793867, -0.2884458689964175, '32.7%'),
#   Text(0.4149945797413191, -0.43333531910672357, '25.7%')])
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'area'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'stories'}>,
#         <AxesSubplot:title={'center':'parking'}>]], dtype=object)

# %%
plt.figure(figsize=(25,5))
sns.pairplot(df)
plt.show()
# Out:
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.title('House Price Distribution Plot')
sns.distplot(df["price"])
# Out:
# /var/folders/0_/y_k__7gj6dx7mxn20r43wcd00000gn/T/ipykernel_54215/107525512.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <AxesSubplot:title={'center':'House Price Distribution Plot'}, xlabel='price', ylabel='Density'>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.title('House Price Spread')
sns.boxplot(y=df["price"])
# Out:
# <AxesSubplot:title={'center':'House Price Spread'}, ylabel='price'>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.scatterplot(x=df.bedrooms,y=df.price,hue=df.bedrooms)
plt.grid(color='black', linestyle='-', linewidth=0.25)
plt.xlabel("Bedrooms")
plt.title("Bedrooms - Price\n", fontsize = 15)
plt.ylabel("Price\n", fontsize=15)
# Out:
# Text(0, 0.5, 'Price\n')
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.scatterplot(x=df.bathrooms,y=df.price,hue=df.bathrooms)
plt.grid(color='black', linestyle='-', linewidth=0.25)
plt.xlabel("bathrooms")
plt.title("bathrooms - Price\n", fontsize = 15)
plt.ylabel("Price\n", fontsize=15)
# Out:
# Text(0, 0.5, 'Price\n')
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.scatterplot(x=df.stories,y=df.price,hue=df.stories)
plt.grid(color='black', linestyle='-', linewidth=0.25)
plt.xlabel("stories")
plt.title("stories - Price\n", fontsize = 15)
plt.ylabel("Price\n", fontsize=15)
# Out:
# Text(0, 0.5, 'Price\n')
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.scatter(df.price, df.area)

# %% [markdown]
# <h4> 4. Perform descriptive statistics on the dataset. </h4>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# furnishingstatus    object
# dtype: object

# %% [markdown]
# <h4> 5. Check for Missing values and deal with them. </h4>

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
# No Null Values are present in the dataset

# %% [markdown]
# <h4>6. Find the outliers and replace them outliers</h4>

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
df.shape
# Out:
# (545, 12)

# %%
sns.boxplot(df.area)
# Out:
# <AxesSubplot:>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
per99Area = np.percentile(df.area, 99)
per99Area
# Out:
# 12543.599999999955

# %%
df2 = df[df['area']<=per99Area]
df2.shape
# Out:
# (539, 12)

# %%
sns.boxplot(df2.area)
# Out:
# <AxesSubplot:>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.boxplot(df2.price)
# Out:
# <AxesSubplot:>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
per99Price = np.percentile(df.price, 99)
per99Price
# Out:
# 10541999.999999963

# %%
df2 = df2[df2['price']<=per99Price]
df2.shape
# Out:
# (533, 12)

# %%
df2.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 6   10150000  8580         4          3        4      yes        no       no
# 8    9870000  8100         4          1        2      yes       yes      yes
# 9    9800000  5750         3          2        4      yes       yes       no
# 11   9681000  6000         4          3        2      yes       yes      yes
# 12   9310000  6550         4          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking furnishingstatus
# 6               no             yes        2   semi-furnished
# 8               no             yes        2        furnished
# 9               no             yes        1      unfurnished
# 11             yes              no        2   semi-furnished
# 12              no             yes        1   semi-furnished

# %% [markdown]
# <h4> 7. Check for Categorical columns and perform encoding. </h4>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df2.mainroad = le.fit_transform(df2.mainroad)
df2.guestroom = le.fit_transform(df2.guestroom)
df2.basement = le.fit_transform(df2.basement)
df2.hotwaterheating = le.fit_transform(df2.hotwaterheating)
df2.airconditioning = le.fit_transform(df2.airconditioning)
df2.furnishingstatus = le.fit_transform(df2.furnishingstatus)

# %%
df2.head()
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 6   10150000  8580         4          3        4         1          0
# 8    9870000  8100         4          1        2         1          1
# 9    9800000  5750         3          2        4         1          1
# 11   9681000  6000         4          3        2         1          1
# 12   9310000  6550         4          2        2         1          0
#
#     basement  hotwaterheating  airconditioning  parking  furnishingstatus
# 6          0                0                1        2                 1
# 8          1                0                1        2                 0
# 9          0                0                1        1                 2
# 11         1                1                0        2                 1
# 12         0                0                1        1                 1

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/umesh/Library/Python/3.11/lib/python/site-packages/IPython/core/pylabtools.py:152: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# <h4>8. Split the data
# into dependent and independent variables.</h4>

# %%
Y = df2['price']
X = df2.drop(['price'], axis=1)

# %%
X.head()
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 6   8580         4          3        4         1          0         0
# 8   8100         4          1        2         1          1         1
# 9   5750         3          2        4         1          1         0
# 11  6000         4          3        2         1          1         1
# 12  6550         4          2        2         1          0         0
#
#     hotwaterheating  airconditioning  parking  furnishingstatus
# 6                 0                1        2                 1
# 8                 0                1        2                 0
# 9                 0                1        1                 2
# 11                1                0        2                 1
# 12                0                1        1                 1

# %%
Y.head()
# Out:
# 6     10150000
# 8      9870000
# 9      9800000
# 11     9681000
# 12     9310000
# Name: price, dtype: int64

# %% [markdown]
# <h4>9. Scale the independent
# variables</h4>

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X = ss.fit_transform(X)
X
# Out:
# array([[ 1.83374123,  1.42433351,  3.60770444, ...,  1.49341991,
#          1.57564115, -0.10655584],
#        [ 1.58667998,  1.42433351, -0.57252701, ...,  1.49341991,
#          1.57564115, -1.42735259],
#        [ 0.37710929,  0.06137164,  1.51758871, ...,  1.49341991,
#          0.39113236,  1.21424092],
#        ...,
#        [-0.71922499, -1.30159022, -0.57252701, ..., -0.66960404,
#         -0.79337643,  1.21424092],
#        [-1.08466976,  0.06137164, -0.57252701, ..., -0.66960404,
#         -0.79337643, -1.42735259],
#        [-0.60084148,  0.06137164, -0.57252701, ..., -0.66960404,
#         -0.79337643,  1.21424092]])

# %% [markdown]
# <h3> 10. Split the data into training and testing </h3>

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
X_Train.shape
# Out:
# (426, 11)

# %% [markdown]
# <h4> 11. Build the Model </h4>

# %%
from sklearn.preprocessing import PolynomialFeatures
pr=PolynomialFeatures(degree=4)

# %%
X_poly=pr.fit_transform(X)
X_poly
# Out:
# array([[ 1.00000000e+00,  1.83374123e+00,  1.42433351e+00, ...,
#          2.81883146e-02, -1.90629030e-03,  1.28916636e-04],
#        [ 1.00000000e+00,  1.58667998e+00,  1.42433351e+00, ...,
#          5.05798067e+00, -4.58195817e+00,  4.15073565e+00],
#        [ 1.00000000e+00,  3.77109289e-01,  6.13716412e-02, ...,
#          2.25557475e-01,  7.00226178e-01,  2.17379939e+00],
#        ...,
#        [ 1.00000000e+00, -7.19224995e-01, -1.30159022e+00, ...,
#          9.28043473e-01, -1.42034515e+00,  2.17379939e+00],
#        [ 1.00000000e+00, -1.08466976e+00,  6.13716412e-02, ...,
#          1.28239297e+00,  2.30713550e+00,  4.15073565e+00],
#        [ 1.00000000e+00, -6.00841481e-01,  6.13716412e-02, ...,
#          9.28043473e-01, -1.42034515e+00,  2.17379939e+00]])

# %%
pr.fit(X_poly,Y)
# Out:
# PolynomialFeatures(degree=4)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %% [markdown]
# <h4> 12. Train the Model <h4>

# %%
lr.fit(X_poly,Y)
# Out:
# LinearRegression()

# %% [markdown]
# <h4> 13. Test the Model </h4>

# %%
Y_pred=lr.predict(X_poly)

# %%
Y_pred
# Out:
# array([10150061.74609375,  9870057.2265625 ,  9800058.0546875 ,
#         9681067.24609375,  9310060.70703125,  9240035.6171875 ,
#         9240060.77734375,  9100059.6484375 ,  9100061.4296875 ,
#         8960058.9921875 ,  8890062.8671875 ,  8855060.58984375,
#         8750058.24609375,  8680060.2421875 ,  8645058.2421875 ,
#         8645060.6171875 ,  8575061.2109375 ,  8540058.1796875 ,
#         8463056.74609375,  7614620.2109375 ,  8400012.6796875 ,
#         8400059.82421875,  8400057.5546875 ,  8400058.87109375,
#         8295058.4453125 ,  8190069.6796875 ,  8120058.4296875 ,
#         8080998.0546875 ,  8043071.6171875 ,  7980059.1796875 ,
#         7962560.6796875 ,  7910057.83984375,  7875058.4609375 ,
#         7840059.0234375 ,  7700058.5546875 ,  7700059.30859375,
#         7560059.8984375 ,  7560061.52734375,  7525061.0234375 ,
#         7490058.3671875 ,  7455059.5625    ,  7420060.49609375,
#         7420059.6171875 ,  7420058.6796875 ,  7350060.3671875 ,
# ...

# %% [markdown]
# <h4> 14. Measure the performance using Metrics. </h4>

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(Y, Y_pred)
# Out:
# 0.9831849257219546

# %%
mean_squared_error(Y, Y_pred)
# Out:
# 47758323212.3939
